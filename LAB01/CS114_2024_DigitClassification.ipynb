# %% [markdown]
# # MÔ TẢ BÀI TOÁN
#
# - Input: Chữ số viết tay
# - Output: Kết quả nhận dạng
#
# Tham khảo: https://machinelearningmastery.com/how-to-develop-a-convolutional-neural-network-from-scratch-for-mnist-handwritten-digit-classification/
#
# ![image.png](data:image/png;base64,...)

# %%
# Change #0
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # MNIST Handwritten Digit Classification Dataset
#
# - Các ảnh greyscale có kích thước 28x28

# %%
from tensorflow.keras.datasets import mnist
from matplotlib import pyplot as plt

# load dataset
(trainX, trainy), (testX, testy) = mnist.load_data()

# summarize loaded dataset
print('Train: X=%s, y=%s' % (trainX.shape, trainy.shape))
print('Test: X=%s, y=%s' % (testX.shape, testy.shape))

# plot first few images
for i in range(9):
  # define subplot
  plt.subplot(330 + 1 + i)
  # plot raw pixel data
  plt.imshow(trainX[i], cmap=plt.get_cmap('gray'))
  # show the figure
  plt.show()
# Out:
# Train: X=(60000, 28, 28), y=(60000,)
# Test: X=(10000, 28, 28), y=(10000,)

# %%
from numpy import mean
from numpy import std
from matplotlib import pyplot as plt
from sklearn.model_selection import KFold
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import SGD
from numpy import argmax
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import load_model

# %% [markdown]
# ## Load Dataset
#
# - we know that the images are all pre-aligned (e.g. each image only contains a hand-drawn digit), that the images all have the same square size of 28×28 pixels, and that the images are grayscale. Therefore, we can load the images and reshape the data arrays to have a single color channel.
# - a one hot encoding for the class element of each sample, transforming the integer into a 10 element binary vector with a 1 for the index of the class value, and 0 values for all other classes

# %%
def load_dataset():
  # load dataset
  (trainX, trainY), (testX, testY) = mnist.load_data()

  # reshape dataset to have a single channel
  trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
  testX = testX.reshape((testX.shape[0], 28, 28, 1))

  # one hot encode target values
  trainY = to_categorical(trainY)
  testY = to_categorical(testY)
  return trainX, trainY, testX, testY

# %% [markdown]
# ## Prepare Pixel Data
#
# - We know that the pixel values for each image in the dataset are unsigned integers in the range between black and white, or 0 and 255.
#
# - We do not know the best way to scale the pixel values for modeling, but we know that some scaling will be required.
#
# - A good starting point is to normalize the pixel values of grayscale images, e.g. rescale them to the range [0,1]. This involves first converting the data type from unsigned integers to floats, then dividing the pixel values by the maximum value.

# %%
def prep_pixels(train, test):
  # convert from integers to floats
  train_norm = train.astype('float32')
  test_norm = test.astype('float32')

  # normalize to range 0-1
  train_norm = train_norm / 255.0
  test_norm = test_norm / 255.0

  # return normalized images
  return train_norm, test_norm

# %% [markdown]
# ## Define Model

# %%
def define_model():
  model = Sequential()
  model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
  model.add(MaxPooling2D((2, 2)))
  model.add(Flatten())
  model.add(Dense(100, activation='relu', kernel_initializer='he_uniform'))
  model.add(Dense(10, activation='softmax'))

  # compile model
  opt = SGD(learning_rate=0.01, momentum=0.9)
  model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

  return model

# %% [markdown]
# ## Evaluate Model

# %%
# evaluate a model using k-fold cross-validation
def evaluate_model(dataX, dataY, n_folds=5):
  scores, histories = list(), list()

  # prepare cross validation
  kfold = KFold(n_folds, shuffle=True, random_state=1)

  # enumerate splits
  for train_ix, test_ix in kfold.split(dataX):

    # define model
    model = define_model()

    # select rows for train and test
    trainX, trainY, testX, testY = dataX[train_ix], dataY[train_ix], dataX[test_ix], dataY[test_ix]

    # fit model
    history = model.fit(trainX, trainY, epochs=10, batch_size=32, validation_data=(testX, testY), verbose=0)

    # evaluate model
    _, acc = model.evaluate(testX, testY, verbose=0)
    print('> %.3f' % (acc * 100.0))

    # stores scores
    scores.append(acc)
    histories.append(history)

  return scores, histories

# %% [markdown]
# ## Present Results

# %%
def summarize_diagnostics(histories):
  for i in range(len(histories)):
    # plot loss
    plt.subplot(2, 1, 1)
    plt.title('Cross Entropy Loss')
    plt.plot(histories[i].history['loss'], color='blue', label='train')
    plt.plot(histories[i].history['val_loss'], color='orange', label='test')

    # plot accuracy
    plt.subplot(2, 1, 2)
    plt.title('Classification Accuracy')
    plt.plot(histories[i].history['accuracy'], color='blue', label='train')
    plt.plot(histories[i].history['val_accuracy'], color='orange', label='test')
    plt.show()

# %%
def summarize_performance(scores):
  # print summary
  print('Accuracy: mean=%.3f std=%.3f, n=%d' % (mean(scores)*100, std(scores)*100, len(scores)))

  # box and whisker plots of results
  plt.boxplot(scores)
  plt.show()

# %%
def run_test_harness():
  # load dataset
  trainX, trainY, testX, testY = load_dataset()

  # prepare pixel data
  trainX, testX = prep_pixels(trainX, testX)

  # evaluate model
  scores, histories = evaluate_model(trainX, trainY)

  # learning curves
  summarize_diagnostics(histories)

  # summarize estimated performance
  summarize_performance(scores)

# %%
# entry point, run the test harness
run_test_harness()
# Out:
# > 98.608
# > 98.633
# > 98.475
# > 98.892
# > 98.625
# Accuracy: mean=98.647 std=0.135, n=5

# %% [markdown]
# ## Save Final Model

# %%
# run the test harness for evaluating a model
def run_test_harness2():
  # load dataset
  trainX, trainY, testX, testY = load_dataset()

  # prepare pixel data
  trainX, testX = prep_pixels(trainX, testX)
  # define model
  model = define_model()

  # fit model
  model.fit(trainX, trainY, epochs=10, batch_size=32, verbose=0)

  # save model
  model.save('final_model.h5')

# %% [markdown]
# ## Evaluate Final Model

# %%
run_test_harness2()
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Make Prediction

# %%
# Change #1

from PIL import Image

def resize_with_more_accurate(filename):
  # Load the image
  img = Image.open(filename)

  # Convert the image to grayscale using the ITU-R BT.709 color space
  img = img.convert('L')

  # Resize the image using bilinear interpolation
  new_width = 28
  new_height = 28
  img = img.resize((new_width, new_height), Image.BILINEAR)

  # Save the resized image
  img.save('temp.png')

# %%
def load_image(filename, reversed_grayscale=False):
  # Change #2
  
  # load the image
  resize_with_more_accurate(filename)
  img = load_img('temp.png', color_mode='grayscale', target_size=(28, 28))

  # convert to array
  img = img_to_array(img)
  
  # Change #3
  # reverse grayscale
  if reversed_grayscale:
    img = 255 - img
  
  # reshape into a single sample with 1 channel
  img = img.reshape(1, 28, 28, 1)

  # prepare pixel data
  img = img.astype('float32')
  img = img / 255.0

  return img

# %%
# Change #4

def show_image(img):    
  img2 = img.reshape(28, 28)
  plt.imshow(img2, cmap = 'gray')
  plt.show()

# %%
# load an image and predict the class
def run_example():
  # load the image
  # Change #5

  img = load_image('sample_image.png', reversed_grayscale=True)
  show_image(img)
  # load model
  model = load_model('final_model.h5')

  # predict the class
  predict_value = model.predict(img)

  digit = argmax(predict_value)
  print(digit)

# %%
# entry point, run the example
run_example()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 0

# %% [markdown]
# Testing reversed_grayscale=False

# %%
# Change #6

# Loading model and data folder
testFolder = 'data'
import glob
model = load_model('final_model.h5')

# Extracting student IDs
correct = []
wrong = []
MSSVs = glob.glob(f'{testFolder}/*')
MSSVs = [name[-8:] for name in MSSVs]

# Iterating through dataset
for MSSV in MSSVs:
  for i in range(10):
    files = glob.glob(f'{testFolder}/{MSSV}/{i}/*')
    for f in files:
      img = load_image(f, reversed_grayscale=False) #reversed_grayscale=False
      predict_value = model.predict(img)
      digit = argmax(predict_value)
      # Output the prediction
      if digit == i:
        print('Correct: ', f, '-', digit)
        correct.append(f)
      else:
        print('Wrong:', f, '-' , digit)
        wrong.append(f)
print('Correct: ', len(correct))
print('Wrong:', len(wrong))
print('Accuracy: ', len(correct)/90)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Wrong: data/22520488/0\0(2).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22520488/0\0(3).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22520488/0\0.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22520488/1\1(2).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520488/1\1(3).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22520488/1\1.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Wrong: data/22520488/2\2(2).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22520488/2\2(3).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22520488/2\2.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520488/3\3(2).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22520488/3\3(3).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22520488/3\3.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22520488/4\4(2).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22520488/4\4(3).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22520488/4\4.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Wrong: data/22520488/5\5(2).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Wrong: data/22520488/5\5(3).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Wrong: data/22520488/5\5.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22520488/6\6(2).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520488/6\6(3).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22520488/6\6.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Wrong: data/22520488/7\7(2).png - 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Wrong: data/22520488/7\7(3).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520488/7\7.png - 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Wrong: data/22520488/8\8(2).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520488/8\8(3).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22520488/8\8.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Wrong: data/22520488/9\9(2).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520488/9\9(3).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22520488/9\9.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520619/0\1.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22520619/0\2.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520619/0\3.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22520619/1\1.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520619/1\2.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Wrong: data/22520619/1\3.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22520619/2\1.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Wrong: data/22520619/2\2.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520619/2\3.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520619/3\1.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22520619/3\2.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22520619/3\3.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520619/4\1.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520619/4\2.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22520619/4\3.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22520619/5\1.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22520619/5\2.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22520619/5\3.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520619/6\1.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520619/6\2.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22520619/6\3.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22520619/7\1.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22520619/7\2.png - 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520619/7\3.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520619/8\1.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520619/8\2.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Correct:  data/22520619/8\3.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22520619/9\1.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520619/9\2.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520619/9\3.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22521005/0\0(0).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22521005/0\0(1).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22521005/0\0(2).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22521005/1\1(0).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22521005/1\1(1).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22521005/1\1(2).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22521005/2\2(0).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22521005/2\2(1).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22521005/2\2(2).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22521005/3\3(0).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22521005/3\3(1).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22521005/3\3(2).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22521005/4\4(0).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22521005/4\4(1).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Wrong: data/22521005/4\4(2).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22521005/5\5(0).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Wrong: data/22521005/5\5(1).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Wrong: data/22521005/5\5(2).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22521005/6\6(0).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22521005/6\6(1).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22521005/6\6(2).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22521005/7\7(0).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22521005/7\7(1).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22521005/7\7(2).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22521005/8\8(0).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22521005/8\8(1).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22521005/8\8(2).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Correct:  data/22521005/9\9(0).png - 9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22521005/9\9(1).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22521005/9\9(2).png - 3
# Correct:  10
# Wrong: 80
# Accuracy:  0.1111111111111111

# %% [markdown]
# Testing reversed_grayscale=True

# %%
correct = []
wrong = []
MSSVs = glob.glob(f'{testFolder}/*')
MSSVs = [name[-8:] for name in MSSVs]

# Iterating through dataset
for MSSV in MSSVs:
  for i in range(10):
    files = glob.glob(f'{testFolder}/{MSSV}/{i}/*')
    for f in files:
      img = load_image(f, reversed_grayscale=True) #reversed_grayscale=True
      predict_value = model.predict(img)
      digit = argmax(predict_value)
      # Output the prediction
      if digit == i:
        print('Correct: ', f, '-', digit)
        correct.append(f)
      else:
        print('Wrong:', f, '-' , digit)
        wrong.append(f)
        #show_image(img)

# Output overall result
print('Correct: ', len(correct))
print('Wrong:', len(wrong))
print('Accuracy: ', len(correct)/90)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520488/0\0(2).png - 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22520488/0\0(3).png - 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Correct:  data/22520488/0\0.png - 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Correct:  data/22520488/1\1(2).png - 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Correct:  data/22520488/1\1(3).png - 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520488/1\1.png - 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Correct:  data/22520488/2\2(2).png - 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Correct:  data/22520488/2\2(3).png - 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Correct:  data/22520488/2\2.png - 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22520488/3\3(2).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Correct:  data/22520488/3\3(3).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22520488/3\3.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520488/4\4(2).png - 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520488/4\4(3).png - 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520488/4\4.png - 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520488/5\5(2).png - 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520488/5\5(3).png - 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22520488/5\5.png - 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22520488/6\6(2).png - 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22520488/6\6(3).png - 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520488/6\6.png - 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Correct:  data/22520488/7\7(2).png - 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520488/7\7(3).png - 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22520488/7\7.png - 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520488/8\8(2).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520488/8\8(3).png - 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22520488/8\8.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520488/9\9(2).png - 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Wrong: data/22520488/9\9(3).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520488/9\9.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Correct:  data/22520619/0\1.png - 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520619/0\2.png - 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Wrong: data/22520619/0\3.png - 9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Correct:  data/22520619/1\1.png - 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Correct:  data/22520619/1\2.png - 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520619/1\3.png - 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520619/2\1.png - 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Correct:  data/22520619/2\2.png - 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22520619/2\3.png - 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22520619/3\1.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520619/3\2.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520619/3\3.png - 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Correct:  data/22520619/4\1.png - 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Correct:  data/22520619/4\2.png - 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Correct:  data/22520619/4\3.png - 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520619/5\1.png - 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22520619/5\2.png - 9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520619/5\3.png - 9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520619/6\1.png - 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520619/6\2.png - 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520619/6\3.png - 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520619/7\1.png - 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Wrong: data/22520619/7\2.png - 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520619/7\3.png - 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Correct:  data/22520619/8\1.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22520619/8\2.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22520619/8\3.png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22520619/9\1.png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22520619/9\2.png - 9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22520619/9\3.png - 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22521005/0\0(0).png - 9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Correct:  data/22521005/0\0(1).png - 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Correct:  data/22521005/0\0(2).png - 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Correct:  data/22521005/1\1(0).png - 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22521005/1\1(1).png - 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22521005/1\1(2).png - 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22521005/2\2(0).png - 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22521005/2\2(1).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22521005/2\2(2).png - 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Wrong: data/22521005/3\3(0).png - 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22521005/3\3(1).png - 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Correct:  data/22521005/3\3(2).png - 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22521005/4\4(0).png - 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Wrong: data/22521005/4\4(1).png - 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Correct:  data/22521005/4\4(2).png - 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22521005/5\5(0).png - 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22521005/5\5(1).png - 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22521005/5\5(2).png - 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Correct:  data/22521005/6\6(0).png - 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22521005/6\6(1).png - 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Correct:  data/22521005/6\6(2).png - 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22521005/7\7(0).png - 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22521005/7\7(1).png - 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Correct:  data/22521005/7\7(2).png - 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22521005/8\8(0).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Correct:  data/22521005/8\8(1).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Correct:  data/22521005/8\8(2).png - 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Wrong: data/22521005/9\9(0).png - 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Correct:  data/22521005/9\9(1).png - 9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Correct:  data/22521005/9\9(2).png - 9
# Correct:  67
# Wrong: 23
# Accuracy:  0.7444444444444445

# %% [markdown]
# # Các thay đổi đã thực hiện trên Notebook:
#
# ### Change #0
# Loại bỏ tất cả warning.
# ### Change #1
# Resize hình ảnh về size 28x28, dùng ITU-R BT.709 color space của thư viện Pillow để đạt được grayscale chính xác hơn, lưu tạm vào file temp.png.<br>
# Lí do: Không gian màu mặc định khi chuyển sang grayscale bị vàng màu ảnh.
# ### Change #2
# Thay đổi lời gọi hàm với tham số thêm reversed_grayscale, load ảnh temp.png.<br>
# Lí do: Do tập ảnh train là nền đen chữ trắng.
# ### Change #3
# Do dataset là nền trắng chữ đen thay vì nền đen chữ trăng như bộ MNIST dùng để train, dùng để đảo ngược màu hình lại để đạt được accuracy cao hơn.
# ### Change #4
# Thêm hàm xuất ảnh.
# ### Change #5
# Lời gọi hàm trong run_example được thêm tham số reversed_grayscale để đạt độ chính xác cao hơn.
# ### Change #6
# Thêm cell test model bằng dataset tự tạo:
# - Với tham số reversed_grayscale=False, độ chính xác chỉ là 0.11
# - Với tham số reversed_grayscale=True, độ chính xác được tăng lên thành 0.74
